# %%
# !pip install git+https://github.com/Frankothe196/auto-sklearn.git@python3.10-added-compatibility;

# One of the things I was struggling was installing autosklearn in python.
# Thanks to "wbaumche", I was able to install it using the code above.
# Out:
# ...
#   Cloning https://github.com/Frankothe196/auto-sklearn.git (to revision python3.10-added-compatibility) to /tmp/pip-req-build-lnq4xoof
#   Running command git clone --filter=blob:none --quiet https://github.com/Frankothe196/auto-sklearn.git /tmp/pip-req-build-lnq4xoof
#   Running command git checkout -b python3.10-added-compatibility --track origin/python3.10-added-compatibility
#   Switched to a new branch 'python3.10-added-compatibility'
#   Branch 'python3.10-added-compatibility' set up to track remote branch 'python3.10-added-compatibility' from 'origin'.
#   Resolved https://github.com/Frankothe196/auto-sklearn.git to commit 80a575760e99945fa31970b1479edeb759bc645a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
import sklearn.model_selection
from sklearn.datasets import fetch_openml
import sklearn.metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder

# %%
X, y = fetch_openml(data_id=40691, as_frame=True, return_X_y=True)
enc = OneHotEncoder(handle_unknown='ignore')
#X = enc.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
X
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
# dtypes: float64(11)
# memory usage: 137.5 KB

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: class, Length: 1599, dtype: category
# Categories (6, object): ['3', '4', '5', '6', '7', '8']

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
y_hat = clf.predict(X_test)
print("RF Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# RF Accuracy 0.67

# %%
## Problem
from autosklearn.classification import AutoSklearnClassifier

automl = AutoSklearnClassifier(time_left_for_this_task =300)
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("AutoML Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/target_validator.py:187: UserWarning: Fitting transformer with a pandas series which has the dtype category. Inverse transform may not be able preserve dtype when converting to np.ndarray
#   warnings.warn(
# Fitting to the training data: 100%|██████████| 300/300 [04:53<00:00,  1.02it/s, The total time budget for this task is 0:05:00]
# AutoML Accuracy 0.6

# %%
## Trial Solution 1

automl = AutoSklearnClassifier(time_left_for_this_task =600,
                               ensemble_size = 50,
                               per_run_time_limit = 60)
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("AutoML Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# <ipython-input-22-a4d3883a30e8>:3: DeprecationWarning: `ensemble_size` has been deprecated, please use `ensemble_kwargs = {'ensemble_size': 50}`. Inserting `ensemble_size` into `ensemble_kwargs` for now. `ensemble_size` will be removed in auto-sklearn 0.16.
#   automl = AutoSklearnClassifier(time_left_for_this_task =600,
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/target_validator.py:187: UserWarning: Fitting transformer with a pandas series which has the dtype category. Inverse transform may not be able preserve dtype when converting to np.ndarray
#   warnings.warn(
# Fitting to the training data: 100%|██████████| 600/600 [09:50<00:00,  1.02it/s, The total time budget for this task is 0:10:00]
# AutoML Accuracy 0.6525

# %%
## Trial Solution 2

automl = AutoSklearnClassifier(time_left_for_this_task =300,
                               ensemble_size = 400,
                               resampling_strategy = 'cv')
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("AutoML Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# <ipython-input-29-30f9f50884cf>:3: DeprecationWarning: `ensemble_size` has been deprecated, please use `ensemble_kwargs = {'ensemble_size': 400}`. Inserting `ensemble_size` into `ensemble_kwargs` for now. `ensemble_size` will be removed in auto-sklearn 0.16.
#   automl = AutoSklearnClassifier(time_left_for_this_task =300,
# /usr/local/lib/python3.10/dist-packages/autosklearn/data/target_validator.py:187: UserWarning: Fitting transformer with a pandas series which has the dtype category. Inverse transform may not be able preserve dtype when converting to np.ndarray
#   warnings.warn(
# Fitting to the training data: 100%|██████████| 300/300 [04:54<00:00,  1.02it/s, The total time budget for this task is 0:05:00]
# AutoML Accuracy 0.6775

# %%
## Trial Solution 3

automl = AutoSklearnClassifier(time_left_for_this_task =200,
                               ensemble_size = 50,
                               resampling_strategy = 'cv')
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("AutoML Accuracy", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# <ipython-input-33-a6e7223dbb95>:3: DeprecationWarning: `ensemble_size` has been deprecated, please use `ensemble_kwargs = {'ensemble_size': 50}`. Inserting `ensemble_size` into `ensemble_kwargs` for now. `ensemble_size` will be removed in auto-sklearn 0.16.
#   automl = AutoSklearnClassifier(time_left_for_this_task =200,
# Fitting to the training data:   0%|          | 0/200 [00:00<?, ?it/s, The total time budget for this task is 0:03:20]/usr/local/lib/python3.10/dist-packages/autosklearn/data/target_validator.py:187: UserWarning: Fitting transformer with a pandas series which has the dtype category. Inverse transform may not be able preserve dtype when converting to np.ndarray
#   warnings.warn(
# Fitting to the training data: 100%|██████████| 200/200 [03:14<00:00,  1.03it/s, The total time budget for this task is 0:03:20]
# AutoML Accuracy 0.675

# %%
# The issue with the fail.py is that Onehot Encoder was applied on a dataset that is numeric. From the dataset, there was no
# categorical variable (as shown by X.info()).
# Also, the variables are on different scale which AutoML may not do during the preprocessing stage of the AutoML, hence the
# data was scaled for all variables to have the same denomination.
# A resampling strategy "cv" was also employed.

# At the end of the AutoML process, we have the following results in terms of accuracy:

# Random Forest = 67%

# AutoML
# Trail Solution 1 = 65.25 (The low accuracy might be due to the number of ensemble used)
# Trail Solution 2 = 67.75 (The best performing)
# Trail Solution 3 = 67.50
